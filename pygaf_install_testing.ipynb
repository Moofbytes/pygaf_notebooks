# %% [markdown]
# # PyGAF Install Testing

# %%
import pygaf

# %%
help(pygaf)
# Out:
# Help on package pygaf:
#
# NAME
#     pygaf - PyGAF - Python Groundwater Analytic Flow.
#
# DESCRIPTION
#     Python package for evaluation and display of analytic solutions for
#     groundwater flow.
#
#     Repository: https://github.com/Moofbytes/PyGAF
#     Documentation: https://pygaf.readthedocs.io/en/latest/index.html
#
# PACKAGE CONTENTS
#     aquifers
#     basins
#     bcs
#     grids
#     solutions (package)
#     stresses
#     utils
#     wells
#
# SUBMODULES
#     glover_1960
#     mine_flow
#     steady_flow
#     theis_1935
#
# FILE
#     /Users/Tony/anaconda3/lib/python3.7/site-packages/pygaf/__init__.py

# %%
dir(pygaf)
# Out:
# ['Aq1dFiniteConf',
#  'Aq1dFiniteUnconf',
#  'Aq1dSemifiniteConf',
#  'Aq1dSemifiniteUnconf',
#  'Aq2dConf',
#  'Aq2dLeaky',
#  'Aq2dUnconf',
#  'Aquifer',
#  'BasinGrid',
#  'CircBasin',
#  'GloverRectBasinSteady',
#  'MineSteadyRadLeakyDD',
#  'MineSteadyRadUnconfQ',
#  'MineSteadyRadUnconfQ2',
#  'MineSteadyStripLeakyDD',
#  'MineSteadyStripLeakyQ',
#  'MineSteadyStripUnconfQ',
#  'MineTransRadConfDD',
#  'MineTransStripConfQ',
#  'MineTransStripLeakyQ',
#  'MineTransStripUnconfQ',
#  'RectBasin',
#  'Steady1dConfFlow',
#  'SteadyBC',
#  'SteadyWell',
#  'StressSeries',
#  'TheisWell',
#  'TransientWell',
#  'Well',
#  'WellGrid',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'aquifers',
#  'basins',
#  'bcs',
#  'glover_1960',
#  'grids',
#  'mine_flow',
#  'pygaf',
#  'solutions',
#  'steady_flow',
#  'stresses',
#  'theis_1935',
#  'utils',
#  'wells']

# %%
W1 = pygaf.SteadyWell()
W1.info()
# Out:
# WELL INFORMATION
# ----------------
# Type: Steady state
# Name: Steady state flowing well
# Coordinates: 0.0 , 0.0
# Radius: 0.05 [L]
# Penetration: 1
# Well rate: 0.0 [L3/T]
# State: off

# %%
S1 = pygaf.TheisWell()
S1.dd()
# Out:
#              r1
# Time
# 1    -79.732203

# %%
S1.dd_grid()
# Out:
#          x      y      radius  drawdown
# 0   -100.0 -100.0  141.421356 -4.454537
# 1    -90.0 -100.0  134.536240 -4.948152
# 2    -80.0 -100.0  128.062485 -5.458301
# 3    -70.0 -100.0  122.065556 -5.974643
# 4    -60.0 -100.0  116.619038 -6.483539
# ..     ...    ...         ...       ...
# 436   60.0  100.0  116.619038 -6.483539
# 437   70.0  100.0  122.065556 -5.974643
# 438   80.0  100.0  128.062485 -5.458301
# 439   90.0  100.0  134.536240 -4.948152
# 440  100.0  100.0  141.421356 -4.454537
#
# [441 rows x 4 columns]
