# %% [markdown]
# # PyGAF Install Testing

# %%
import pygaf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-bbb34165122e> in <module>
# ----> 1 import pygaf
#
# ModuleNotFoundError: No module named 'pygaf'

# %%
help(pygaf)

# %%
dir(pygaf)
# Out:
# ['Aq1dFiniteConf',
#  'Aq1dFiniteUnconf',
#  'Aq1dSemifiniteConf',
#  'Aq1dSemifiniteUnconf',
#  'Aq2dConf',
#  'Aq2dUnconf',
#  'Aquifer',
#  'Basin',
#  'BasinGrid',
#  'CircBasin',
#  'GloverRectBasinSteady',
#  'RectBasin',
#  'SteadyWell',
#  'StressSeries',
#  'TheisWell',
#  'TransientWell',
#  'Well',
#  'WellGrid',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'aquifers',
#  'basins',
#  'glover_1960',
#  'grids',
#  'solutions',
#  'stresses',
#  'theis_1935',
#  'wells']

# %%
w1 = pygaf.SteadyWell()
w1.info()
# Out:
# WELL INFORMATION
# ----------------
# Type: Steady state
# Name: unnamed
# Coordinates: 0.0 , 0.0
# Radius: 0.05 [L]
# Penetration: 1
# Well rate: 0.0 [L3/T]
# State: off

# %%
s1 = pygaf.TheisWell()
s1.dd()
# Out:
#              r1
# Time
# 1    -79.732203

# %%
s1.dd_grid()
# Out:
#          x      y      radius  drawdown
# 0   -100.0 -100.0  141.421356 -4.454537
# 1    -90.0 -100.0  134.536240 -4.948152
# 2    -80.0 -100.0  128.062485 -5.458301
# 3    -70.0 -100.0  122.065556 -5.974643
# 4    -60.0 -100.0  116.619038 -6.483539
# ..     ...    ...         ...       ...
# 436   60.0  100.0  116.619038 -6.483539
# 437   70.0  100.0  122.065556 -5.974643
# 438   80.0  100.0  128.062485 -5.458301
# 439   90.0  100.0  134.536240 -4.948152
# 440  100.0  100.0  141.421356 -4.454537
#
# [441 rows x 4 columns]
