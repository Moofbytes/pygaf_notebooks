# %% [markdown]
# # 1D Steady Aquifer Flow
# This notebook demonstrates steady state boundary value solutions for 1D aquifer flow using the `Steady1dConfFlow` and `Steady1dUnconfFlow` classes.

# %% [markdown]
# Installed `PyGAF` testing.

# %%
import os
import pygaf
# %matplotlib inline

# %% [markdown]
# Local testing.

# %%
import os
import sys
sys.path.insert(0, os.path.abspath('../pygaf'))
import pygaf

# %% [markdown]
# ## Confined Flow
# The default `Steady1dConfFlow` object uses the default `Aq1dFiniteConf` aquifer class, default `SteadyBC` type 2 boundary condition class at x=0 and default `SteadyBC` type 1 boundary condition class at x=L.
#
# Create a default steady state, 1D confined aquifer flow solution and display the default solution information.

# %%
Sol1 = pygaf.Steady1dConfFlow()
Sol1.info()
# Out:
# FLOW SOLUTION INFORMATION
# -------------------------
# Flow in 1D, finite, confined homogeneous aquifer
# BC at x=0: type 2, {'flow': 0.0}
# BC at x=L: type 1, {'head': 10.0}
# Recharge rate: 0.0 [L/T]

# %% [markdown]
# Use the `.info` methods of the boundary and aquifer objects.

# %%
Sol1.bc0.info()
Sol1.bcL.info()
Sol1.aq.info()
# Out:
# BOUNDARY CONDITION INFORMATION
# ------------------------------
# BC type 2, {'flow': 0.0}
#
# BOUNDARY CONDITION INFORMATION
# ------------------------------
# BC type 1, {'head': 10.0}
#
# AQUIFER INFORMATION
# -------------------
# Type: 1D, finite, confined homogeneous aquifer
# Name: Aq1dFiniteConf class
# Hydraulic conductivity: 1 [L/T]
# Specific storativity: 0.0001 [1/L]
# Thickness: 10 [L]
# Length: 1000 [L]
# Transmissivity: 10 [L2/T]
# Storage coefficient: 0.001 [1]
# Diffusivity: 10000.0 [L2/T]
# Bottom elevation: 0 [RL]
# Top elevation: 10 [RL]

# %% [markdown]
# Draw the aquifer.

# %%
Sol1.aq.draw()

# %% [markdown]
# Calculate the solutions for head, flow and hydraulic gradient; plots are drawn as default but can be suppressed using the `plot=False` argument.

# %%
H1 = Sol1.h()
Q1 = Sol1.q()
G1 = Sol1.h_grad()

# %% [markdown]
# ### Solution for head at x=L, no-flow at x=0 and uniform recharge

# %%
Sol2 = pygaf.Steady1dConfFlow()
Sol2.R = 0.0001
Sol2.info()
H2 = Sol2.h()
Q2 = Sol2.q()
G2 = Sol2.h_grad()
# Out:
# FLOW SOLUTION INFORMATION
# -------------------------
# Flow in 1D, finite, confined homogeneous aquifer
# BC at x=0: type 2, {'flow': 0.0}
# BC at x=L: type 1, {'head': 10.0}
# Recharge rate: 0.0001 [L/T]

# %% [markdown]
# Soluitions are returned in a Pandas dataframe.

# %%
print(Q2)
# Out:
#               x         q
# 0      0.000000  0.000000
# 1     41.666667  0.004167
# 2     83.333333  0.008333
# 3    125.000000  0.012500
# 4    166.666667  0.016667
# 5    208.333333  0.020833
# 6    250.000000  0.025000
# 7    291.666667  0.029167
# 8    333.333333  0.033333
# 9    375.000000  0.037500
# 10   416.666667  0.041667
# 11   458.333333  0.045833
# 12   500.000000  0.050000
# 13   541.666667  0.054167
# 14   583.333333  0.058333
# 15   625.000000  0.062500
# 16   666.666667  0.066667
# 17   708.333333  0.070833
# 18   750.000000  0.075000
# 19   791.666667  0.079167
# 20   833.333333  0.083333
# 21   875.000000  0.087500
# 22   916.666667  0.091667
# 23   958.333333  0.095833
# 24  1000.000000  0.100000

# %% [markdown]
# ### Solution for head at x=L, inflow at x=0 and uniform recharge

# %%
Sol4 = pygaf.Steady1dConfFlow()
Sol4.bc0.flow = 0.05
Sol4.R = 0.0001
Sol4.info()
H4 = Sol4.h()
Q4 = Sol4.q()
G4 = Sol4.h_grad()
print(Q4)
# Out:
# FLOW SOLUTION INFORMATION
# -------------------------
# Flow in 1D, finite, confined homogeneous aquifer
# BC at x=0: type 2, {'flow': 0.05}
# BC at x=L: type 1, {'head': 10.0}
# Recharge rate: 0.0001 [L/T]
#               x         q
# 0      0.000000  0.050000
# 1     41.666667  0.054167
# 2     83.333333  0.058333
# 3    125.000000  0.062500
# 4    166.666667  0.066667
# 5    208.333333  0.070833
# 6    250.000000  0.075000
# 7    291.666667  0.079167
# 8    333.333333  0.083333
# 9    375.000000  0.087500
# 10   416.666667  0.091667
# 11   458.333333  0.095833
# 12   500.000000  0.100000
# 13   541.666667  0.104167
# 14   583.333333  0.108333
# 15   625.000000  0.112500
# 16   666.666667  0.116667
# 17   708.333333  0.120833
# 18   750.000000  0.125000
# 19   791.666667  0.129167
# 20   833.333333  0.133333
# 21   875.000000  0.137500
# 22   916.666667  0.141667
# 23   958.333333  0.145833
# 24  1000.000000  0.150000

# %% [markdown]
# ### Solution for head at x=L, outflow at x=0 and uniform recharge
# Outflow at x=0 is achieved by setting the boundary flow to a negative value.

# %%
Sol5 = pygaf.Steady1dConfFlow()
Sol5.bc0.flow = -0.03
Sol5.R = 0.0001
Sol5.info()
H5 = Sol5.h()
Q5 = Sol5.q()
G5 = Sol5.h_grad()
print(Q5)
# Out:
# FLOW SOLUTION INFORMATION
# -------------------------
# Flow in 1D, finite, confined homogeneous aquifer
# BC at x=0: type 2, {'flow': -0.03}
# BC at x=L: type 1, {'head': 10.0}
# Recharge rate: 0.0001 [L/T]
#               x         q
# 0      0.000000 -0.030000
# 1     41.666667 -0.025833
# 2     83.333333 -0.021667
# 3    125.000000 -0.017500
# 4    166.666667 -0.013333
# 5    208.333333 -0.009167
# 6    250.000000 -0.005000
# 7    291.666667 -0.000833
# 8    333.333333  0.003333
# 9    375.000000  0.007500
# 10   416.666667  0.011667
# 11   458.333333  0.015833
# 12   500.000000  0.020000
# 13   541.666667  0.024167
# 14   583.333333  0.028333
# 15   625.000000  0.032500
# 16   666.666667  0.036667
# 17   708.333333  0.040833
# 18   750.000000  0.045000
# 19   791.666667  0.049167
# 20   833.333333  0.053333
# 21   875.000000  0.057500
# 22   916.666667  0.061667
# 23   958.333333  0.065833
# 24  1000.000000  0.070000

# %% [markdown]
# ### Solution for head at x=L, head at x=0 and uniform recharge

# %%
Sol6 = pygaf.Steady1dConfFlow()
Sol6.bc0.type = 1
Sol6.bcL.type = 1
Sol6.bc0.head = 15
Sol6.R = 0.0005
Sol6.info()
H6 = Sol6.h()
Q6 = Sol6.q()
G6 = Sol6.h_grad()
print(Q6)
# Out:
# FLOW SOLUTION INFORMATION
# -------------------------
# Flow in 1D, finite, confined homogeneous aquifer
# BC at x=0: type 1, {'head': 15}
# BC at x=L: type 1, {'head': 10.0}
# Recharge rate: 0.0005 [L/T]
#               x         q
# 0      0.000000 -0.200000
# 1     41.666667 -0.179167
# 2     83.333333 -0.158333
# 3    125.000000 -0.137500
# 4    166.666667 -0.116667
# 5    208.333333 -0.095833
# 6    250.000000 -0.075000
# 7    291.666667 -0.054167
# 8    333.333333 -0.033333
# 9    375.000000 -0.012500
# 10   416.666667  0.008333
# 11   458.333333  0.029167
# 12   500.000000  0.050000
# 13   541.666667  0.070833
# 14   583.333333  0.091667
# 15   625.000000  0.112500
# 16   666.666667  0.133333
# 17   708.333333  0.154167
# 18   750.000000  0.175000
# 19   791.666667  0.195833
# 20   833.333333  0.216667
# 21   875.000000  0.237500
# 22   916.666667  0.258333
# 23   958.333333  0.279167
# 24  1000.000000  0.300000

# %% [markdown]
# ## Unconfined Flow
# The default `Steady1dUnconfFlow` object uses the default `Aq1dFiniteUnconf` aquifer class, default `SteadyBC` type 2 boundary condition class at x=0 and default `SteadyBC` type 1 boundary condition class at x=L.
#
# Create a default steady state, 1D confined aquifer flow solution and display the default solution information.

# %%
Sol7 = pygaf.Steady1dUnconfFlow()
Sol7.info()
# Out:
# FLOW SOLUTION INFORMATION
# -------------------------
# Flow in 1D, finite, unconfined homogeneous aquifer
# BC at x=0: type 2, {'flow': 0.0}
# BC at x=L: type 1, {'head': 10.0}
# Recharge rate: 0.0 [L/T]

# %%
Sol7.aq.draw()

# %% [markdown]
# Calculate the solutions for head, flow and hydraulic gradient; plots are drawn as default but can be suppressed using the `plot=False` argument.

# %%
H7 = Sol1.h()
Q7 = Sol1.q()
G7 = Sol1.h_grad()

# %% [markdown]
# ### Solution for head at x=L, no-flow at x=0 and uniform recharge

# %%
Sol8 = pygaf.Steady1dUnconfFlow()
Sol8.R = 0.0001
Sol8.info()
H8 = Sol8.h()
Q8 = Sol8.q()
G8 = Sol8.h_grad()
print(Q8)
# Out:
# FLOW SOLUTION INFORMATION
# -------------------------
# Flow in 1D, finite, unconfined homogeneous aquifer
# BC at x=0: type 2, {'flow': 0.0}
# BC at x=L: type 1, {'head': 10.0}
# Recharge rate: 0.0001 [L/T]
#               x         q
# 0      0.000000  0.000000
# 1     41.666667  0.004167
# 2     83.333333  0.008333
# 3    125.000000  0.012500
# 4    166.666667  0.016667
# 5    208.333333  0.020833
# 6    250.000000  0.025000
# 7    291.666667  0.029167
# 8    333.333333  0.033333
# 9    375.000000  0.037500
# 10   416.666667  0.041667
# 11   458.333333  0.045833
# 12   500.000000  0.050000
# 13   541.666667  0.054167
# 14   583.333333  0.058333
# 15   625.000000  0.062500
# 16   666.666667  0.066667
# 17   708.333333  0.070833
# 18   750.000000  0.075000
# 19   791.666667  0.079167
# 20   833.333333  0.083333
# 21   875.000000  0.087500
# 22   916.666667  0.091667
# 23   958.333333  0.095833
# 24  1000.000000  0.100000

# %% [markdown]
# ### Solution for head at x=L, inflow at x=0 and uniform recharge

# %%
Sol9 = pygaf.Steady1dUnconfFlow()
Sol9.bc0.flow = 0.05
Sol9.R = 0.0001
Sol9.info()
H9 = Sol9.h()
Q9 = Sol9.q()
G9 = Sol9.h_grad()
print(Q9)
# Out:
# FLOW SOLUTION INFORMATION
# -------------------------
# Flow in 1D, finite, unconfined homogeneous aquifer
# BC at x=0: type 2, {'flow': 0.05}
# BC at x=L: type 1, {'head': 10.0}
# Recharge rate: 0.0001 [L/T]
#               x         q
# 0      0.000000  0.050000
# 1     41.666667  0.054167
# 2     83.333333  0.058333
# 3    125.000000  0.062500
# 4    166.666667  0.066667
# 5    208.333333  0.070833
# 6    250.000000  0.075000
# 7    291.666667  0.079167
# 8    333.333333  0.083333
# 9    375.000000  0.087500
# 10   416.666667  0.091667
# 11   458.333333  0.095833
# 12   500.000000  0.100000
# 13   541.666667  0.104167
# 14   583.333333  0.108333
# 15   625.000000  0.112500
# 16   666.666667  0.116667
# 17   708.333333  0.120833
# 18   750.000000  0.125000
# 19   791.666667  0.129167
# 20   833.333333  0.133333
# 21   875.000000  0.137500
# 22   916.666667  0.141667
# 23   958.333333  0.145833
# 24  1000.000000  0.150000

# %% [markdown]
# ### Solution for head at x=L, outflow at x=0 and uniform recharge
# Outflow at x=0 is achieved by setting the boundary flow to a negative value.

# %%
Sol10 = pygaf.Steady1dUnconfFlow()
Sol10.bc0.flow = -0.03
Sol10.R = 0.0001
Sol10.info()
H10 = Sol10.h()
Q10 = Sol10.q()
G10 = Sol10.h_grad()
print(Q10)
# Out:
# FLOW SOLUTION INFORMATION
# -------------------------
# Flow in 1D, finite, unconfined homogeneous aquifer
# BC at x=0: type 2, {'flow': -0.03}
# BC at x=L: type 1, {'head': 10.0}
# Recharge rate: 0.0001 [L/T]
#               x         q
# 0      0.000000 -0.030000
# 1     41.666667 -0.025833
# 2     83.333333 -0.021667
# 3    125.000000 -0.017500
# 4    166.666667 -0.013333
# 5    208.333333 -0.009167
# 6    250.000000 -0.005000
# 7    291.666667 -0.000833
# 8    333.333333  0.003333
# 9    375.000000  0.007500
# 10   416.666667  0.011667
# 11   458.333333  0.015833
# 12   500.000000  0.020000
# 13   541.666667  0.024167
# 14   583.333333  0.028333
# 15   625.000000  0.032500
# 16   666.666667  0.036667
# 17   708.333333  0.040833
# 18   750.000000  0.045000
# 19   791.666667  0.049167
# 20   833.333333  0.053333
# 21   875.000000  0.057500
# 22   916.666667  0.061667
# 23   958.333333  0.065833
# 24  1000.000000  0.070000

# %% [markdown]
# ### Solution for head at x=L, head at x=0 and uniform recharge

# %%
Sol11 = pygaf.Steady1dUnconfFlow()
Sol11.bc0.type = 1
Sol11.bcL.type = 1
Sol11.bc0.head = 15
Sol11.R = 0.0005
Sol11.info()
H11 = Sol11.h()
Q11 = Sol11.q()
G11 = Sol11.h_grad()
print(G11)
# Out:
# FLOW SOLUTION INFORMATION
# -------------------------
# Flow in 1D, finite, unconfined homogeneous aquifer
# BC at x=0: type 1, {'head': 15}
# BC at x=L: type 1, {'head': 10.0}
# Recharge rate: 0.0005 [L/T]
#               x    h_grad
# 0      0.000000 -0.016500
# 1     41.666667 -0.014639
# 2     83.333333 -0.012946
# 3    125.000000 -0.011385
# 4    166.666667 -0.009925
# 5    208.333333 -0.008544
# 6    250.000000 -0.007225
# 7    291.666667 -0.005951
# 8    333.333333 -0.004711
# 9    375.000000 -0.003491
# 10   416.666667 -0.002283
# 11   458.333333 -0.001073
# 12   500.000000  0.000147
# 13   541.666667  0.001391
# 14   583.333333  0.002670
# 15   625.000000  0.004000
# 16   666.666667  0.005399
# 17   708.333333  0.006889
# 18   750.000000  0.008500
# 19   791.666667  0.010273
# 20   833.333333  0.012264
# 21   875.000000  0.014559
# 22   916.666667  0.017295
# 23   958.333333  0.020707
# 24  1000.000000  0.025250
