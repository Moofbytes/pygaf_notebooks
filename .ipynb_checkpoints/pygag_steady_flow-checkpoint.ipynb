# %% [markdown]
# # 1D Steady Aquifer Flow
# This notebook demonstrates steady state boundary value solutions for 1D aquifer flow using the `Steady1dConfFlow` class.

# %% [markdown]
# Installed `PyGAF` testing.

# %%
import os
import pygaf
# %matplotlib inline

# %% [markdown]
# Local testing.

# %%
import os
import sys
sys.path.insert(0, os.path.abspath('../pygaf'))
import pygaf

# %% [markdown]
# The default `Steady1dConfFlow` object uses the default `Aq1dFiniteConf` aquifer class, default `SteadyBC` type 2 boundary condition class at x=0 and default `SteadyBC` type 1 boundary condition class at x=L.
#
# Create a default steady state, 1D confined aquifer flow solution and display the default solution information.

# %%
Sol1 = pygaf.Steady1dConfFlow()
Sol1.info()
# Out:
# SOLUTION INFORMATION
# --------------------
# Flow in 1D, finite, confined homogeneous aquifer
# BC at x=0: type 2, {'flow': 0.0}
# BC at x=L: type 1, {'head': 10.0}
# Recharge rate: 0.0 [L/T]

# %% [markdown]
# Or use the `.info` methods of the boundary and aquifer objects.

# %%
Sol1.bc0.info()
Sol1.bcL.info()
Sol1.aq.info()
# Out:
# BOUNDARY CONDITION INFORMATION
# ------------------------------
# BC type 2, {'flow': 0.0}
#
# BOUNDARY CONDITION INFORMATION
# ------------------------------
# BC type 1, {'head': 10.0}
#
# AQUIFER INFORMATION
# -------------------
# Type: 1D, finite, confined homogeneous aquifer
# Name: Aq1dFiniteConf class
# Hydraulic conductivity: 1 [L/T]
# Specific storativity: 0.0001 [1/L]
# Thickness: 10 [L]
# Length: 1000 [L]
# Transmissivity: 10 [L2/T]
# Storage coefficient: 0.001 [1]
# Diffusivity: 10000.0 [L2/T]
# Bottom elevation: 0 [RL]
# Top elevation: 10 [RL]

# %% [markdown]
# Draw the solution setup.

# %%
Sol1.aq.draw()

# %% [markdown]
# Calculate the solution. The solution is plotted as default but can be suppressed using the `plot=False` argument
# - Head
# - Flow
# - Gradient of head

# %%
H = Sol1.h()
Q = Sol1.q()
G =Sol1.h_grad()

# %% [markdown]
# ### Solution for head at x=L, no-flow at x=0 and uniform recharge

# %%
Sol2 = pygaf.Steady1dConfFlow()
Sol2.R = 0.0001
Sol2.info()
H2 = Sol2.h()
Q2 = Sol2.q()
G2 = Sol2.h_grad()
# Out:
# SOLUTION INFORMATION
# --------------------
# Flow in 1D, finite, confined homogeneous aquifer
# BC at x=0: type 2, {'flow': 0.0}
# BC at x=L: type 1, {'head': 10.0}
# Recharge rate: 0.0001 [L/T]

# %% [markdown]
# Soluitions are returned in a Pandas dataframe.

# %%
print(H2)
# Out:
#               x          h
# 0      0.000000  15.000000
# 1     41.666667  14.991319
# 2     83.333333  14.965278
# 3    125.000000  14.921875
# 4    166.666667  14.861111
# 5    208.333333  14.782986
# 6    250.000000  14.687500
# 7    291.666667  14.574653
# 8    333.333333  14.444444
# 9    375.000000  14.296875
# 10   416.666667  14.131944
# 11   458.333333  13.949653
# 12   500.000000  13.750000
# 13   541.666667  13.532986
# 14   583.333333  13.298611
# 15   625.000000  13.046875
# 16   666.666667  12.777778
# 17   708.333333  12.491319
# 18   750.000000  12.187500
# 19   791.666667  11.866319
# 20   833.333333  11.527778
# 21   875.000000  11.171875
# 22   916.666667  10.798611
# 23   958.333333  10.407986
# 24  1000.000000  10.000000

# %% [markdown]
# **Swap the boundary condition and re-evaluate the solution**

# %%
Sol3 = pygaf.Steady1dConfFlow()
Sol3.bc0.type = 1
Sol3.bcL.type = 2
Sol3.R = 0.0001
Sol3.info()
H3 = Sol3.h()
Q3 = Sol3.q()
G3 = Sol3.h_grad()
# Out:
# SOLUTION INFORMATION
# --------------------
# Flow in 1D, finite, confined homogeneous aquifer
# BC at x=0: type 1, {'head': 10.0}
# BC at x=L: type 2, {'flow': 0.0}
# Recharge rate: 0.0001 [L/T]

# %% [markdown]
# ### Solution for head at x=L, inflow at x=0 and uniform recharge

# %%
Sol4 = pygaf.Steady1dConfFlow()
Sol4.bc0.flow = 0.05
Sol4.R = 0.0001
Sol4.info()
H4 = Sol4.h()
Q4 = Sol4.q()
G4 = Sol4.h_grad()
# Out:
# SOLUTION INFORMATION
# --------------------
# Flow in 1D, finite, confined homogeneous aquifer
# BC at x=0: type 2, {'flow': 0.05}
# BC at x=L: type 1, {'head': 10.0}
# Recharge rate: 0.0001 [L/T]

# %% [markdown]
# ### Solution for head at x=L, outflow at x=0 and uniform recharge

# %%
Sol5 = pygaf.Steady1dConfFlow()
Sol5.bc0.flow = -0.03
Sol5.R = 0.0001
Sol5.info()
H5 = Sol5.h()
Q5 = Sol5.q()
G5 = Sol5.h_grad()
# Out:
# SOLUTION INFORMATION
# --------------------
# Flow in 1D, finite, confined homogeneous aquifer
# BC at x=0: type 2, {'flow': -0.03}
# BC at x=L: type 1, {'head': 10.0}
# Recharge rate: 0.0001 [L/T]

# %% [markdown]
# ### Solution for head at x=L, head at x=0 and uniform recharge

# %%
Sol6 = pygaf.Steady1dConfFlow()
Sol6.bc0.type = 1
Sol6.bcL.type = 1
Sol6.info()
H6 = Sol6.h()
Q6 = Sol6.q()
G6 = Sol6.h_grad()
# Out:
# SOLUTION INFORMATION
# --------------------
# Flow in 1D, finite, confined homogeneous aquifer
# BC at x=0: type 1, {'head': 10.0}
# BC at x=L: type 1, {'head': 10.0}
# Recharge rate: 0.0 [L/T]

# %%
Sol6.bc0.head = 15
Sol6.R = 0.0005
Sol6.info()
H6 = Sol6.h()
Q6 = Sol6.q()
G6 = Sol6.h_grad()
print(H6)
# Out:
# SOLUTION INFORMATION
# --------------------
# Flow in 1D, finite, confined homogeneous aquifer
# BC at x=0: type 1, {'head': 15}
# BC at x=L: type 1, {'head': 10.0}
# Recharge rate: 0.0005 [L/T]
#               x          h
# 0      0.000000  15.000000
# 1     41.666667  15.789931
# 2     83.333333  16.493056
# 3    125.000000  17.109375
# 4    166.666667  17.638889
# 5    208.333333  18.081597
# 6    250.000000  18.437500
# 7    291.666667  18.706597
# 8    333.333333  18.888889
# 9    375.000000  18.984375
# 10   416.666667  18.993056
# 11   458.333333  18.914931
# 12   500.000000  18.750000
# 13   541.666667  18.498264
# 14   583.333333  18.159722
# 15   625.000000  17.734375
# 16   666.666667  17.222222
# 17   708.333333  16.623264
# 18   750.000000  15.937500
# 19   791.666667  15.164931
# 20   833.333333  14.305556
# 21   875.000000  13.359375
# 22   916.666667  12.326389
# 23   958.333333  11.206597
# 24  1000.000000  10.000000
