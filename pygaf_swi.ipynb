# %% [markdown]
# # Saltwater Abrupt Interface
# This notebook demonstrates saltwater abrupt interface solutions using the `name` and `name` classes.

# %% [markdown]
# Installed `PyGAF` testing.

# %%
import os
import pygaf
# %matplotlib inline

# %% [markdown]
# Local testing.

# %%
import os
import sys
sys.path.insert(0, os.path.abspath('../pygaf'))
import pygaf

# %% [markdown]
# ## Glover (1959) Abrupt Interface Solution
# The default `GloverSWI` object uses the `Aq1dFiniteUnconf` aquifer class.
#
# Create a default GloverSWI interface solution and display the default solution information.

# %%
S1 = pygaf.GloverSWI()
S1.info()
# Out:
# METHOD REFERENCE
# ----------------
# Glover (1959) - The Pattern of Fresh-water Flow in a Coastal Aquifer.
#
# Conceptual Model:
# - Immiscible fluids with abrupt interface.
# - Static saltwater.
# - Hydrostatic pressure.
# - Steady state flow.
# - Homogeneous and isotropic aquifer.
# - Seepage face between shoreline and interface.

# %% [markdown]
# Interface solution.

# %%
dum = S1.swi()
# Out:
# Freshwater density: 1000.0
# Saltwater density: 1023.0
# Density ratio: 0.023
# Aquifer hydraulic conductivity: 1.0
# Freshwater discharge: 0.2
# Length of freshwater seepage face: 4.35

# %% [markdown]
# Increase the number of x locations for evaluating the solution.

# %%
S1.n = 50
dum = S1.swi()
# Out:
# Freshwater density: 1000.0
# Saltwater density: 1023.0
# Density ratio: 0.023
# Aquifer hydraulic conductivity: 1.0
# Freshwater discharge: 0.2
# Length of freshwater seepage face: 4.35

# %% [markdown]
# Change hydraulic conductivity, aquifer discharge and saltwater density.

# %%
S1.K = 0.5
S1.Q = 0.3
S1.rho_salt = 1025
dum = S1.swi()
# Out:
# Freshwater density: 1000.0
# Saltwater density: 1025
# Density ratio: 0.025
# Aquifer hydraulic conductivity: 0.5
# Freshwater discharge: 0.3
# Length of freshwater seepage face: 12.0
